# %%
import pandas as pd
import dabl
import os

# %%
from dabl import plot
from dabl.datasets import load_ames
import matplotlib.pyplot as plt

# %%
# Load the Ames housing dataset
data = load_ames()

# Plot SalePrice
plot(data, 'SalePrice')

plt.show()
# Out:
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:622: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# Target looks like regression
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\utils.py:704: UserWarning: Dropped 2 outliers in column SalePrice.
#   warn("Dropped {} outliers in column {}.".format(
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:652: UserWarning: Discarding 2 outliers in target column.
#   warn(f"Discarding {n_outliers} outliers in target column.",
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:111: UserWarning: Showing only top 10 continuous features.
#   warn("Showing only top 10 continuous features.")
# Showing only top 10 of 41 categorical features
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = X_new.groupby(col)[target_col].median()

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_digits
X, y = load_digits(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
sc = dabl.SimpleClassifier().fit(X_train, y_train)

print("Accuracy score", sc.score(X_test, y_test))
# Out:
# Running DummyClassifier()
# accuracy: 0.106 recall_macro: 0.100 precision_macro: 0.011 f1_macro: 0.019
# === new best DummyClassifier() (using recall_macro):
# accuracy: 0.106 recall_macro: 0.100 precision_macro: 0.011 f1_macro: 0.019
#
# Running GaussianNB()
# accuracy: 0.834 recall_macro: 0.836 precision_macro: 0.854 f1_macro: 0.833
# === new best GaussianNB() (using recall_macro):
# accuracy: 0.834 recall_macro: 0.836 precision_macro: 0.854 f1_macro: 0.833
#
# Running MultinomialNB()
# accuracy: 0.897 recall_macro: 0.899 precision_macro: 0.904 f1_macro: 0.898
# === new best MultinomialNB() (using recall_macro):
# accuracy: 0.897 recall_macro: 0.899 precision_macro: 0.904 f1_macro: 0.898
#
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=1)
# accuracy: 0.196 recall_macro: 0.199 precision_macro: 0.076 f1_macro: 0.099
# Running DecisionTreeClassifier(class_weight='balanced', max_depth=10)
# accuracy: 0.839 recall_macro: 0.840 precision_macro: 0.842 f1_macro: 0.839
# Running DecisionTreeClassifier(class_weight='balanced', min_impurity_decrease=0.01)
# accuracy: 0.777 recall_macro: 0.778 precision_macro: 0.792 f1_macro: 0.778
# Running LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000)
# accuracy: 0.956 recall_macro: 0.956 precision_macro: 0.959 f1_macro: 0.957
# === new best LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000) (using recall_macro):
# accuracy: 0.956 recall_macro: 0.956 precision_macro: 0.959 f1_macro: 0.957
#
# Running LogisticRegression(C=1, class_weight='balanced', max_iter=1000)
# accuracy: 0.964 recall_macro: 0.964 precision_macro: 0.966 f1_macro: 0.964
# === new best LogisticRegression(C=1, class_weight='balanced', max_iter=1000) (using recall_macro):
# accuracy: 0.964 recall_macro: 0.964 precision_macro: 0.966 f1_macro: 0.964
#
#
# Best model:
# LogisticRegression(C=1, class_weight='balanced', max_iter=1000)
# Best Scores:
# accuracy: 0.964 recall_macro: 0.964 precision_macro: 0.966 f1_macro: 0.964
# Accuracy score 0.9777777777777777

# %% [markdown]
# ## Loading the Dataset

# %% [markdown]
# ## Solubility dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/master/delaney_solubility_with_descriptors.csv')

# %%
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %%
plot(df, 'logS')
# Out:
# Target looks like regression
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:622: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# [<Axes: title={'center': 'Target distribution'}, xlabel='logS', ylabel='frequency'>,
#  array([[<Axes: title={'center': 'F=-8.45E-01'}, xlabel='MolLogP', ylabel='logS'>,
#          <Axes: title={'center': 'F=-6.76E-01'}, xlabel='MolWt'>,
#          <Axes: title={'center': 'F=-2.48E-01'}, xlabel='AromaticProportion'>,
#          <Axes: title={'center': 'F=-1.76E-01'}, xlabel='NumRotatableBonds (jittered)'>]],
#        dtype=object),
#  None]

# %% [markdown]
# ## Penguine Dataset

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'dabl - A Python library for AutoEDA and AutoML.ipynb',
#  'penguins_cleaned.xlsx']

# %%
df = pd.read_excel('penguins_cleaned.xlsx')

# %%
df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8                207
# 329  Chinstrap      Dream            43.5           18.1                202
# 330  Chinstrap      Dream            49.6           18.2                193
# 331  Chinstrap      Dream            50.8           19.0                210
# 332  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 0           3750    male
# 1           3800  female
# 2           3250  female
# 3           3450  female
# 4           3650    male
# ..           ...     ...
# 328         4000    male
# 329         3400  female
# 330         3775    male
# 331         4100    male
# 332         3775  female
#
# [333 rows x 7 columns]

# %%
plot(df, 'species')
# Out:
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\supervised.py:622: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\preprocessing.py:172: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(series[:10])
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\utils.py:607: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in data.groupby(target)[column]:
# Target looks like classification
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\utils.py:607: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in data.groupby(target)[column]:
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\utils.py:607: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in data.groupby(target)[column]:
# C:\Users\rajib\AppData\Local\Programs\Python\Python312\Lib\site-packages\dabl\plot\utils.py:607: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for name, group in data.groupby(target)[column]:
# Linear Discriminant Analysis training set score: 0.983
# [<Axes: title={'center': 'Target distribution'}, xlabel='count', ylabel='species'>,
#  [array([[<Axes: ylabel='bill_length_mm'>, <Axes: >, <Axes: >, <Axes: >],
#          [<Axes: ylabel='bill_depth_mm'>, <Axes: >, <Axes: >, <Axes: >],
#          [<Axes: ylabel='flipper_length_mm'>, <Axes: >, <Axes: >, <Axes: >],
#          [<Axes: xlabel='bill_length_mm', ylabel='body_mass_g'>,
#           <Axes: xlabel='bill_depth_mm'>,
#           <Axes: xlabel='flipper_length_mm'>, <Axes: xlabel='body_mass_g'>]],
#         dtype=object),
#   <Figure size 1600x400 with 4 Axes>,
#   <Figure size 400x400 with 1 Axes>],
#  array([[<Axes: title={'center': 'island'}>,
#          <Axes: title={'center': 'sex'}>]], dtype=object)]

# %%
                                                                # The End #
